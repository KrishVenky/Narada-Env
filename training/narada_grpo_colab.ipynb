# %% [markdown]
# # Narada — GRPO Training Notebook
#
# **Meta × PyTorch OpenEnv Hackathon × Scaler School of Technology**
#
# Trains Qwen3-1.7B as the Detective agent on the Narada rare-disease diagnosis environment using GRPO (Group Relative Policy Optimisation).
#
# ## Setup requirements
# - Colab: A100 or L4 (≥16 GB VRAM). T4 works but is slow.
# - Runtime: GPU, High-RAM
#
# ## What this notebook does
# 1. Loads `Qwen/Qwen3-1.7B` with Unsloth 4-bit quantisation
# 2. Connects to the live Narada environment at `https://krishvenky-narada-env.hf.space`
# 3. Runs GRPO training in curriculum order: `monogenic → oligogenic → phenotype_mismatch`
# 4. Evaluates on held-out seeds after each phase
# 5. Pushes the trained LoRA adapter to your HF Hub

# %%
# ── Cell 1: Install dependencies ──────────────────────────────────────────────
# Run once. Restart runtime after this cell.

# !pip install -q \
    "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git" \
    "trl>=0.9.0" \
    "peft>=0.10.0" \
    "accelerate>=0.30.0" \
    "bitsandbytes>=0.43.0" \
    "websockets>=12.0" \
    "pydantic>=2.7.0" \
    "openai>=1.30.0"

print("Install complete — restart runtime now if this is the first run.")
# Out:
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.12/dist-packages)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.12/dist-packages)
# Install complete — restart runtime now if this is the first run.

# %%
# ── Cell 2: Configuration ─────────────────────────────────────────────────────

import os

# ---------- Required: set your HF token ----------
HF_TOKEN = os.environ.get("HF_TOKEN") or input("Paste your HF token (write access): ").strip()
os.environ["HF_TOKEN"] = HF_TOKEN

# ---------- Model ----------
BASE_MODEL = "Qwen/Qwen3-1.7B"        # base model for training
ADAPTER_NAME    = "narada-detective-lora"     # local adapter save name
HF_PUSH_REPO    = ""                          # optional: "YourUser/narada-detective"

# ---------- Environment ----------
ENV_URL         = "https://krishvenky-narada-env.hf.space"

# ---------- Training ----------
LORA_RANK       = 16
MAX_SEQ_LEN     = 2048
GRPO_BATCH_SIZE = 4     # number of completions per prompt (G)
MINI_BATCH_SIZE = 2
GRAD_ACCUM      = 4
LR              = 5e-6
WARMUP_STEPS    = 20

CURRICULUM = [
    {"task": "monogenic",          "steps": 80,  "max_ep_steps": 15},
    {"task": "oligogenic",         "steps": 60,  "max_ep_steps": 25},
    {"task": "phenotype_mismatch", "steps": 60,  "max_ep_steps": 20},
]

EVAL_SEEDS = [42, 7, 999, 1337, 2024]  # held-out seeds for evaluation

print(f"Config ready. Base model: {BASE_MODEL}")
# Out:
# Config ready. Base model: Qwen/Qwen3-1.7B

# %%
# ── Cell 3: Load model with Unsloth ──────────────────────────────────────────
import os
os.environ["UNSLOTH_DISABLE_STATISTICS"] = "1"

from unsloth import FastLanguageModel
import torch

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name      = BASE_MODEL,
    max_seq_length  = MAX_SEQ_LEN,
    dtype           = None,          # auto: bf16 on A100/L4, fp16 on T4
    load_in_4bit    = True,
    token           = HF_TOKEN,
)

model = FastLanguageModel.get_peft_model(
    model,
    r               = LORA_RANK,
    target_modules  = ["q_proj", "k_proj", "v_proj", "o_proj",
                       "gate_proj", "up_proj", "down_proj"],
    lora_alpha      = LORA_RANK * 2,
    lora_dropout    = 0.0,
    bias            = "none",
    use_gradient_checkpointing = "unsloth",
    random_state    = 42,
)

print(f"Model loaded. Trainable params: {sum(p.numel() for p in model.parameters() if p.requires_grad):,}")

# Hard-disable Qwen3 thinking — prevents <think> tokens eating all 600 tokens
_orig_apply = tokenizer.apply_chat_template
def _apply_no_think(*args, **kwargs):
    kwargs["enable_thinking"] = False
    return _orig_apply(*args, **kwargs)
tokenizer.apply_chat_template = _apply_no_think
print("Thinking mode disabled.")
# Out:
# ==((====))==  Unsloth 2026.4.8: Fast Qwen3 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/310 [00:00<?, ?it/s]
# unsloth/qwen3-1.7b-unsloth-bnb-4bit does not have a padding token! Will use pad_token = <|PAD_TOKEN|>.
# Model loaded. Trainable params: 17,432,576
# Thinking mode disabled.

# %%
# ── Cell 4: Environment client + helpers ──────────────────────────────────────

import asyncio, json, re, textwrap
from typing import List, Dict, Any, Optional
import websockets

SYSTEM_PROMPT = textwrap.dedent("""
You are an expert clinical geneticist navigating a gene-disease knowledge graph
to diagnose a rare disease patient.

GRAPH NAVIGATION ACTIONS:
  hop(node_id)            — move to a connected node
  flag_causal(variant_id) — declare the causal variant (terminal, ends episode)
  backtrack()             — return to the previous node
  summarise_trail()       — get a summary of visited nodes

CLINICAL RULES:
  1. Follow phenotype → disease → gene → variant chains.
  2. A high-pathogenicity BRCA1/TP53 variant is a DECOY if phenotypes are cardiac/neurological.
  3. In oligogenic cases you must flag ALL contributing variants.
  4. Act early — correct flags before step 10 earn a timing bonus.

OUTPUT: strict JSON only, no extra text.
{
  "action_type": "hop" | "flag_causal" | "backtrack" | "summarise_trail",
  "node_id": "<id if hop>",
  "variant_id": "<VAR:xxxxx if flag_causal>",
  "reasoning": "<one sentence>"
}
""").strip()


def format_obs(obs: Dict[str, Any]) -> str:
    """Format a raw observation dict into a model prompt string."""
    lines = [
        f"STEP {obs['step']}/{obs['max_steps']} | Task: {obs['task_type']}",
        "",
        "PATIENT PHENOTYPES:",
    ]
    for hid, name in zip(obs["patient_phenotypes"], obs["phenotype_names"]):
        lines.append(f"  {hid} — {name}")

    n = obs["current_node"]
    lines += [
        "",
        f"CURRENT NODE: [{n['type'].upper()}] {n['name']} ({n['id']})",
        f"  Neighbors ({len(n['connected_node_ids'])}): {', '.join(n['connected_node_ids'][:8])}",
    ]

    if obs.get("trail"):
        trail_names = [f"{t['name']}({t['id']})" for t in obs["trail"][-4:]]
        lines.append(f"  Trail: {' → '.join(trail_names)}")

    lines += ["", "CANDIDATE VARIANTS:"]
    for v in obs["candidate_variants"]:
        lines.append(
            f"  {v['id']} | {v['gene']} | {v['variant_type']} "
            f"| path={v['pathogenicity_score']:.2f} | {v['clinical_significance']}"
        )

    lines.append(f"\nStep reward: {obs['step_reward']:+.4f} | Cumulative: {obs['cumulative_reward']:.4f}")
    lines.append("Respond with JSON action.")
    return "\n".join(lines)


def parse_action(text: str) -> Dict[str, Any]:
    m = re.search(r"\{.*\}", text, re.DOTALL)
    if not m:
        return {"action_type": "summarise_trail", "reasoning": "fallback"}
    try:
        d = json.loads(m.group(0))
        atype = str(d.get("action_type", "summarise_trail")).lower()
        if atype not in ("hop", "flag_causal", "backtrack", "summarise_trail"):
            atype = "summarise_trail"
        return {
            "action_type": atype,
            "node_id": str(d["node_id"]) if d.get("node_id") else None,
            "variant_id": str(d["variant_id"]) if d.get("variant_id") else None,
            "reasoning": str(d.get("reasoning", ""))[:200],
        }
    except Exception:
        return {"action_type": "summarise_trail", "reasoning": "parse error"}


async def run_episode_async(
    task_type: str,
    actions: List[Dict[str, Any]],
    seed: Optional[int] = None,
) -> float:
    """
    Replay a list of pre-decided actions in a fresh episode.
    Returns the terminal reward.
    """
    ws_url = ENV_URL.replace("https://", "wss://").replace("http://", "ws://") + "/ws"
    async with websockets.connect(ws_url, open_timeout=30, ping_interval=20) as ws:
        reset_msg = {"type": "reset", "task_type": task_type}
        if seed is not None:
            reset_msg["seed"] = seed
        await ws.send(json.dumps(reset_msg))
        raw = json.loads(await ws.recv())
        if raw.get("type") == "error":
            return 0.1

        obs = raw["data"]["observation"]
        last_reward = 0.1

        for action in actions:
            if obs.get("done"):
                break
            await ws.send(json.dumps({"type": "step", "action": action}))
            raw = json.loads(await ws.recv())
            if raw.get("type") == "error":
                break
            data = raw["data"]
            obs = data["observation"]
            last_reward = data["reward"]
            if obs.get("done"):
                return float(last_reward)

        return float(last_reward)


async def collect_episode_async(
    task_type: str,
    seed: Optional[int] = None,
) -> Dict[str, Any]:
    """
    Run one episode, collecting (prompt, observation) pairs at each step.
    Returns a list of step dicts with 'prompt' and 'obs' keys.
    """
    ws_url = ENV_URL.replace("https://", "wss://").replace("http://", "ws://") + "/ws"
    steps = []
    async with websockets.connect(ws_url, open_timeout=30, ping_interval=20) as ws:
        reset_msg = {"type": "reset", "task_type": task_type}
        if seed is not None:
            reset_msg["seed"] = seed
        await ws.send(json.dumps(reset_msg))
        raw = json.loads(await ws.recv())
        if raw.get("type") == "error":
            return steps
        obs = raw["data"]["observation"]
        steps.append({"prompt": format_obs(obs), "obs": obs, "task_type": task_type, "seed": seed})
    return steps


def run_episode(task_type, actions, seed=None):
    return asyncio.get_event_loop().run_until_complete(
        run_episode_async(task_type, actions, seed)
    )


def collect_episode(task_type, seed=None):
    return asyncio.get_event_loop().run_until_complete(
        collect_episode_async(task_type, seed)
    )


print("Environment helpers loaded.")
# Out:
# Environment helpers loaded.

# %%
# ── Cell 5: Build prompt dataset ─────────────────────────────────────────────
# Collect initial observations from the environment for each task type.
# These become the prompts for GRPO training.
import nest_asyncio
nest_asyncio.apply()

from datasets import Dataset
import random

N_SEEDS_PER_TASK = 20  # 20 seeds × 3 tasks = 60 training prompts
random.seed(42)
train_seeds = random.sample(range(1, 10000), N_SEEDS_PER_TASK * 3)

all_prompts = []
for i, phase in enumerate(CURRICULUM):
    task = phase["task"]
    seeds = train_seeds[i * N_SEEDS_PER_TASK : (i + 1) * N_SEEDS_PER_TASK]
    print(f"Collecting {N_SEEDS_PER_TASK} observations for task={task}...")
    for seed in seeds:
        steps = collect_episode(task, seed=seed)
        if steps:
            all_prompts.append({
                "prompt": [
                    {"role": "system", "content": SYSTEM_PROMPT},
                    {"role": "user",   "content": steps[0]["prompt"]},
                ],
                "task_type": task,
                "seed": seed,
            })

dataset = Dataset.from_list(all_prompts)
print(f"\nDataset: {len(dataset)} prompts across {len(CURRICULUM)} tasks")
print(dataset)
# Out:
# Collecting 20 observations for task=monogenic...
# Collecting 20 observations for task=oligogenic...
# Collecting 20 observations for task=phenotype_mismatch...
#
# Dataset: 60 prompts across 3 tasks
# Dataset({
#     features: ['prompt', 'task_type', 'seed'],
#     num_rows: 60
# })

# %%
import math

def clamp(v: float, lo=0.01, hi=0.99) -> float:
    if not math.isfinite(v):
        return 0.1
    return max(lo, min(hi, v))


def narada_reward(completions, prompts, task_type=None, seed=None, **kwargs):
    rewards = []
    tasks = task_type or ["monogenic"] * len(completions)
    seeds = seed or [None] * len(completions)

    for completion, task, s in zip(completions, tasks, seeds):
        # TRL 0.24+ passes completions as chat message lists
        if isinstance(completion, list):
            text = completion[-1]["content"] if completion else ""
        else:
            text = str(completion)

        action = parse_action(text)
        syntax_bonus = 0.1 if action["action_type"] != "summarise_trail" else 0.0
        env_reward = run_episode(task, [action], seed=s)
        rewards.append(clamp(env_reward + syntax_bonus))

    return rewards


# Sanity check
test_completion = '{"action_type": "summarise_trail", "reasoning": "Getting my bearings."}'
test_reward = narada_reward([test_completion], [[]], task_type=["monogenic"], seed=[1])
print(f"Sanity check reward: {test_reward[0]:.4f} (expect ~0.04–0.15)")
# Out:
# Sanity check reward: 0.0100 (expect ~0.04–0.15)

# %%
from trl import GRPOConfig, GRPOTrainer

grpo_config = GRPOConfig(
    # Core GRPO
    num_generations             = GRPO_BATCH_SIZE,
    temperature                 = 0.9,
    top_p                       = 0.95,

    # Optimiser
    learning_rate               = LR,
    per_device_train_batch_size = MINI_BATCH_SIZE,
    gradient_accumulation_steps = GRAD_ACCUM,
    warmup_steps                = WARMUP_STEPS,
    max_grad_norm               = 0.1,
    optim                       = "adamw_8bit",

    # Sequence
    max_prompt_length           = 1200,
    max_completion_length       = 300,

    # Logging
    logging_steps               = 5,
    output_dir                  = f"outputs/{ADAPTER_NAME}",
    report_to                   = "none",
)

print("GRPOConfig ready.")
# Out:
# GRPOConfig ready.

# %%
# ── Cell 8: Curriculum training ───────────────────────────────────────────────
# Train sequentially: monogenic → oligogenic → phenotype_mismatch.
# Each phase filters the dataset to its task type.

import time

eval_results = {}

for phase in CURRICULUM:
    task = phase["task"]
    n_steps = phase["steps"]

    phase_data = dataset.filter(lambda x: x["task_type"] == task)
    if len(phase_data) == 0:
        print(f"Skipping {task} — no data collected.")
        continue

    print(f"\n{'='*60}")
    print(f"Phase: {task}  |  {len(phase_data)} prompts  |  {n_steps} steps")
    print(f"{'='*60}")

    grpo_config.max_steps = n_steps

    trainer = GRPOTrainer(
        model         = model,
        processing_class = tokenizer,
        reward_funcs  = narada_reward,
        args          = grpo_config,
        train_dataset = phase_data,
    )

    t0 = time.time()
    trainer.train()
    elapsed = time.time() - t0
    print(f"Phase {task} done in {elapsed/60:.1f} min")

    # ── Quick eval on held-out seeds ──────────────────────────────────────────
    FastLanguageModel.for_inference(model)

    phase_scores = []
    print(f"Evaluating on {len(EVAL_SEEDS)} held-out seeds...")
    for es in EVAL_SEEDS:
        steps = collect_episode(task, seed=es)
        if not steps:
            continue
        obs_prompt = steps[0]["prompt"]
        messages = [
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user",   "content": obs_prompt},
        ]
        inputs = tokenizer.apply_chat_template(
            messages, tokenize=True, add_generation_prompt=True,
            return_tensors="pt"
        ).to("cuda")
        with torch.no_grad():
            out = model.generate(inputs, max_new_tokens=200, temperature=0.3)
        completion = tokenizer.decode(out[0][inputs.shape[1]:], skip_special_tokens=True)
        action = parse_action(completion)
        score = run_episode(task, [action], seed=es)
        phase_scores.append(score)

    avg_score = sum(phase_scores) / len(phase_scores) if phase_scores else 0.0
    eval_results[task] = avg_score
    print(f"Eval {task}: avg score = {avg_score:.4f}  (n={len(phase_scores)})")

    # Back to training mode for next phase
    FastLanguageModel.for_training(model)

print("\n=== CURRICULUM COMPLETE ===")
for task, score in eval_results.items():
    print(f"  {task:25s}: {score:.4f}")
# Out:
# Filter:   0%|          | 0/60 [00:00<?, ? examples/s]
# ============================================================
# Phase: monogenic  |  20 prompts  |  80 steps
# ============================================================
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None}.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 20 | Num Epochs = 8 | Total steps = 80
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 17,432,576 of 1,738,007,552 (1.00% trained)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:172: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:202: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:254: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
#     <div>
#
#       <progress value='80' max='80' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [80/80 35:37, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / narada_reward / mean</th>
#       <th>rewards / narada_reward / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.123000</td>
#       <td>0.000000</td>
#       <td>88.975000</td>
#       <td>74.600000</td>
#       <td>99.600000</td>
#       <td>0.000000</td>
#       <td>88.975000</td>
#       <td>74.600000</td>
#       <td>99.600000</td>
#       <td>0.000070</td>
#       <td>0.123000</td>
#       <td>0.013898</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>0.136000</td>
#       <td>0.000000</td>
#       <td>87.875000</td>
#       <td>68.400000</td>
#       <td>106.800000</td>
#       <td>0.000000</td>
#       <td>87.875000</td>
#       <td>68.400000</td>
#       <td>106.800000</td>
#       <td>0.000051</td>
#       <td>0.136000</td>
#       <td>0.027795</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td
td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.000017</td>
#       <td>0.149000</td>
#       <td>0.000000</td>
#       <td>84.875000</td>
#       <td>65.400000</td>
#       <td>105.200000</td>
#       <td>0.000000</td>
#       <td>84.875000</td>
#       <td>65.400000</td>
#       <td>105.200000</td>
#       <td>0.017581</td>
#       <td>0.149000</td>
#       <td>0.013898</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.000021</td>
#       <td>0.136000</td>
#       <td>0.000000</td>
#       <td>88.000000</td>
#       <td>75.800000</td>
#       <td>102.400000</td>
#       <td>0.000000</td>
#       <td>88.000000</td>
#       <td>75.800000</td>
#       <td>102.400000</td>
#       <td>0.020606</td>
#       <td>0.136000</td>
#       <td>0.027795</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.000017</td>
#       <td>0.149000</td>
#       <td>0.000000</td>
#       <td>85.800000</td>
#       <td>68.200000</td>
#       <td>103.200000</td>
#       <td>0.000000</td>
#       <td>85.800000</td>
#       <td>68.200000</td>
#       <td>103.200000</td>
#       <td>0.017901</td>
#       <td>0.149000</td>
#       <td>0.013898</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.001125</td>
#       <td>0.139250</td>
#       <td>0.006500</td>
#       <td>87.650000</td>
#       <td>76.000000</td>
#       <td>101.600000</td>
#       <td>0.000000</td>
#       <td>87.650000</td>
#       <td>76.000000</td>
#       <td>101.600000</td>
#       <td>0.015443</td>
#       <td>0.139250</td>
#       <td>0.036988</td>
#     </tr>
#   </tbody>
# </table><p>
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Restored added_tokens_decoder metadata in outputs/narada-detective-lora/checkpoint-80/tokenizer_config.json.
# Phase monogenic done in 36.1 min
# Evaluating on 5 held-out seeds...
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Both `max_new_tokens` (=200) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# Both `max_new_tokens` (=200) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=200) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=200) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=200) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Eval monogenic: avg score = 0.0100  (n=5)
# Filter:   0%|          | 0/60 [00:00<?, ? examples/s]
# ============================================================
# Phase: oligogenic  |  20 prompts  |  60 steps
# ============================================================
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 20 | Num Epochs = 6 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 17,432,576 of 1,738,007,552 (1.00% trained)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:172: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:202: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:254: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 31:12, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / narada_reward / mean</th>
#       <th>rewards / narada_reward / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>-0.006707</td>
#       <td>0.127000</td>
#       <td>0.012506</td>
#       <td>97.625000</td>
#       <td>78.600000</td>
#       <td>116.600000</td>
#       <td>0.000000</td>
#       <td>97.625000</td>
#       <td>78.600000</td>
#       <td>116.600000</td>
#       <td>0.008789</td>
#       <td>0.127000</td>
#       <td>0.029852</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000008</td>
#       <td>0.123000</td>
#       <td>0.000000</td>
#       <td>84.900000</td>
#       <td>64.000000</td>
#       <td>108.400000</td>
#       <td>0.000000</td>
#       <td>84.900000</td>
#       <td>64.000000</td>
#       <td>108.400000</td>
#       <td>0.008241</td>
#       <td>0.123000</td>
#       <td>0.013898</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0
td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>-0.000722</td>
#       <td>0.142500</td>
#       <td>0.007506</td>
#       <td>96.425000</td>
#       <td>78.400000</td>
#       <td>117.800000</td>
#       <td>0.000000</td>
#       <td>96.425000</td>
#       <td>78.400000</td>
#       <td>117.800000</td>
#       <td>0.015895</td>
#       <td>0.142500</td>
#       <td>0.039831</td>
#     </tr>
#   </tbody>
# </table><p>
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:202: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:254: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:172: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=300) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Phase phenotype_mismatch done in 28.0 min
# Evaluating on 5 held-out seeds...
# Both `max_new_tokens` (=200) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# Both `max_new_tokens` (=200) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=200) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=200) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=200) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Eval phenotype_mismatch: avg score = 0.0620  (n=5)
#
# === CURRICULUM COMPLETE ===
#   monogenic                : 0.0100
#   oligogenic               : 0.0100
#   phenotype_mismatch       : 0.0620

# %%
# ── Cell 9: Save adapter ──────────────────────────────────────────────────────

model.save_pretrained(ADAPTER_NAME)
tokenizer.save_pretrained(ADAPTER_NAME)
print(f"Adapter saved to ./{ADAPTER_NAME}")

# Push to HF Hub (optional — set HF_PUSH_REPO above)
if HF_PUSH_REPO:
    model.push_to_hub(HF_PUSH_REPO, token=HF_TOKEN)
    tokenizer.push_to_hub(HF_PUSH_REPO, token=HF_TOKEN)
    print(f"Adapter pushed to https://huggingface.co/{HF_PUSH_REPO}")
else:
    print("Set HF_PUSH_REPO to push the adapter to HF Hub.")
# Out:
# Unsloth: Restored added_tokens_decoder metadata in narada-detective-lora/tokenizer_config.json.
# Adapter saved to ./narada-detective-lora
# Set HF_PUSH_REPO to push the adapter to HF Hub.

# %%
# ── Cell 10: Full-episode evaluation (post-training) ─────────────────────────
# Run 3 full episodes (one per task) with the trained model.
# Each episode runs until done or max_steps.

from IPython.display import display
import pandas as pd

FastLanguageModel.for_inference(model)

async def run_full_episode_async(task_type: str, seed: int = 0) -> Dict[str, Any]:
    ws_url = ENV_URL.replace("https://", "wss://").replace("http://", "ws://") + "/ws"
    history = []
    conversation = [{"role": "system", "content": SYSTEM_PROMPT}]

    async with websockets.connect(ws_url, open_timeout=30, ping_interval=20) as ws:
        await ws.send(json.dumps({"type": "reset", "task_type": task_type, "seed": seed}))
        raw = json.loads(await ws.recv())
        obs = raw["data"]["observation"]

        while not obs["done"] and obs["step"] < obs["max_steps"]:
            user_text = format_obs(obs)
            conversation.append({"role": "user", "content": user_text})

            inputs = tokenizer.apply_chat_template(
                conversation, tokenize=True, add_generation_prompt=True,
                return_tensors="pt"
            ).to("cuda")
            with torch.no_grad():
                out = model.generate(inputs, max_new_tokens=250, temperature=0.2)
            completion = tokenizer.decode(out[0][inputs.shape[1]:], skip_special_tokens=True)
            conversation.append({"role": "assistant", "content": completion})

            action = parse_action(completion)
            await ws.send(json.dumps({"type": "step", "action": action}))
            raw = json.loads(await ws.recv())
            data = raw["data"]
            obs = data["observation"]
            history.append({"step": obs["step"], "action": action["action_type"], "reward": data["reward"]})

    return {"task": task_type, "steps": len(history), "final_reward": history[-1]["reward"] if history else 0.0, "history": history}


results = []
for task in ["monogenic", "oligogenic", "phenotype_mismatch"]:
    r = asyncio.get_event_loop().run_until_complete(run_full_episode_async(task, seed=42))
    results.append(r)
    print(f"{task:25s}: {r['steps']} steps, final_reward={r['final_reward']:.4f}")

display(pd.DataFrame([{"task": r["task"], "steps": r["steps"], "final_reward": r["final_reward"]} for r in results]))
# Out:
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 2127]) with length 2127 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# monogenic                : 4 steps, final_reward=0.3100
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 2065]) with length 2065 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 2855]) with length 2855 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 3645]) with length 3645 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 4435]) with length 4435 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 5225]) with length 5225 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 6015]) with length 6015 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 6805]) with length 6805 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 7595]) with length 7595 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 8386]) with length 8386 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 9177]) with length 9177 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 9968]) with length 9968 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 10759]) with length 10759 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 11550]) with length 11550 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 12341]) with length 12341 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 13132]) with length 13132 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 13923]) with length 13923 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 14714]) with length 14714 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 15505]) with length 15505 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 16296]) with length 16296 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 17087]) with length 17087 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 17878]) with length 17878 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 18669]) with length 18669 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 19460]) with length 19460 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# oligogenic               : 25 steps, final_reward=0.3600
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 2376]) with length 2376 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 3090]) with length 3090 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 3804]) with length 3804 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 4518]) with length 4518 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 5232]) with length 5232 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 5946]) with length 5946 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 6660]) with length 6660 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 7375]) with length 7375 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 8090]) with length 8090 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 8805]) with length 8805 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 9520]) with length 9520 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 10235]) with length 10235 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 10950]) with length 10950 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 11665]) with length 11665 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 12380]) with length 12380 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 13095]) with length 13095 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Both `max_new_tokens` (=250) and `max_length`(=40960) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Unsloth: Input IDs of shape torch.Size([1, 13810]) with length 13810 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# phenotype_mismatch       : 20 steps, final_reward=0.1500
#                  task  steps  final_reward
# 0           monogenic      4          0.31
# 1          oligogenic     25          0.36
# 2  phenotype_mismatch     20          0.15

# %%
# ── Cell 11: Summary ──────────────────────────────────────────────────────────

print("╔══════════════════════════════════════════════╗")
print("║         NARADA TRAINING COMPLETE              ║")
print("╠══════════════════════════════════════════════╣")
print(f"║  Base model : {BASE_MODEL:<29} ║")
print(f"║  Adapter    : {ADAPTER_NAME:<29} ║")
print("╠══════════════════════════════════════════════╣")
print("║  Post-training eval scores                    ║")
for task, score in eval_results.items():
    print(f"║    {task:25s}: {score:.4f}          ║")
print("╚══════════════════════════════════════════════╝")

if HF_PUSH_REPO:
    print(f"\nModel available at: https://huggingface.co/{HF_PUSH_REPO}")
# Out:
# ╔══════════════════════════════════════════════╗
# ║         NARADA TRAINING COMPLETE              ║
# ╠══════════════════════════════════════════════╣
# ║  Base model : Qwen/Qwen3-1.7B               ║
# ║  Adapter    : narada-detective-lora         ║
# ╠══════════════════════════════════════════════╣
# ║  Post-training eval scores                    ║
# ║    monogenic                : 0.0100          ║
# ║    oligogenic               : 0.0100          ║
# ║    phenotype_mismatch       : 0.0620          ║
# ╚══════════════════════════════════════════════╝
